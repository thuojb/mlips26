# %% [markdown]
# # Kafka Demo
#
# ## Important: Connect to Kafka Broker Server FIRST
#
# **Before running any code in this notebook**, establish an SSH tunnel to the Kafka server:
#
# ```
# ssh -L <local_port>:localhost:<remote_port> <user>@<remote_server> -NTf
# ```
#
# Find connection details (remote_server, user, password, ports) on the Canvas lab 2 assignment page.
#
# **Verify your connection is active:**
# ```bash
# lsof -i :<local_port>  # Should show an ssh process
# ```
#
# **To kill the connection when done:**
# ```
# lsof -ti:<local_port> | xargs kill -9
# ```
#
# ---
#
# ## Setup
#
# It is recommended to set up a python environment for this lab (and all other ones).
# ```
# python -m venv <environment_name>
# source <environment_name>/bin/activate  # On Windows: <environment_name>\Scripts\activate
# ```
#
# Then install the requirements:
# ```
# pip install -r requirements.txt
# ```
# Or manually:
# ```
# pip install kafka-python
# ```

# %%
# !which python   # should point to .lab1/bin/python
# !pip list       # should show notebook/ipykernel installed
# Out:
# /home/thuo/cmu_workspace/spring2026/MLiP/lab2/.lab2/bin/python
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.1.0
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# comm                      0.2.3
# debugpy                   1.8.19
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# ipykernel                 7.1.0
# ipython                   8.38.0
# ipywidgets                8.1.8
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.8.0
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.3
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# kafka-python              2.3.0
# lark                      1.3.1
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.1
# mistune                   3.2.0
# nbclient                  0.10.4
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.5.3
# notebook_shim             0.2.4
# overrides                 7.7.0
# packaging                 26.0
# pandocfilters             1.5.1
# parso                     0.8.5
# pexpect                   4.9.0
# pip                       25.3
# platformdirs              4.5.1
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# psutil                    7.2.1
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 3.0
# Pygments                  2.19.2
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# Send2Trash                2.1.0
# setuptools                59.6.0
# six                       1.17.0
# soupsieve                 2.8.3
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tomli                     2.4.0
# tornado                   6.5.4
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# wcwidth                   0.5.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# widgetsnbextension        4.0.15

# %%
import os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
from kafka import KafkaConsumer, KafkaProducer
from typing import Dict, Any

# [TODO]: Fill in a unique identifier so your topic doesn't collide with others'
# Replace ... with your andrew_id as a string (e.g., "asmith") or any unique identifier
andrew_id = "jthuo"  # Example: andrew_id = "asmith"
topic = f"lab02-{andrew_id}"
print(f"Topic: {topic}")
# Out:
# Topic: lab02-jthuo

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Below schema is for messages. You may change the city data if you wish but it is optional.
def make_city_data(city: str, temperature_f: str) -> Dict[str, Any]:
    return {
        "city": city,
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "temperature_f": temperature_f, # temperature in fahrenheit
    }

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Fill in the address of your Kafka bootstrap server
# [TODO]: Kafka expects messages as bytes. Explore the documentation and decide how to serialize Python dict objects into bytes.
# Hint: You may want to convert your Python dict → JSON string → UTF-8 bytes.

producer = KafkaProducer(bootstrap_servers=["localhost:9092"],
                        value_serializer=lambda v: dumps(v).encode('utf-8'))

# %%
# [TODO]: Add a few more examples of city data below
cities = [make_city_data("Pittsburgh" , 64), make_city_data("Nairobi" , 88), make_city_data("Tokyo" , 60)]

print("Writing to Kafka Broker")
for i in range(10):
    data = cities[randint(0,len(cities)-1)] # random selection
    producer.send(topic=topic, value=data)
    sleep(1)

producer.flush()
print(f"Data written to topic: {topic}")
# Out:
# Writing to Kafka Broker
# Data written to topic: lab02-jthuo

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Fill in the missing parameters:
#   1. First parameter: topic name (should match the topic you used in producer)
#   2. bootstrap_servers: same address you used in producer (e.g., ['localhost:9092'])
#   3. auto_offset_reset: try 'earliest' to read from beginning, 'latest' for new messages only
# Note: Since producer uses value_serializer, message.value is bytes. We decode and parse JSON.

consumer = KafkaConsumer(
    "lab02-jthuo",  # [TODO]: Use your topic variable here
    bootstrap_servers=["localhost:9092"],  # [TODO]: Same bootstrap server as producer
    auto_offset_reset='earliest',  # [TODO]: Try 'earliest', 'latest', or 'none'
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:
    # Producer serialized to JSON bytes, so we decode and parse
    message_str = message.value.decode('utf-8')
    message_dict = loads(message_str)
    print(message_dict)
    os.system(f"echo {message_str} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# {'city': 'Tokyo', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 60}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 60}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 64}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 60}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 64}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 60}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 18:52:31', 'temperature_f': 64}
# {'city': 'London', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 88}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 64}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 60}
# {'city': 'London', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 88}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 64}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 60}
# {'city': 'London', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 88}
# {'city': 'London', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 88}
# {'city': 'London', 'timestamp': '2026-01-27 19:06:34', 'temperature_f': 88}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 64}
# {'city': 'Nairobi', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 88}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 60}
# {'city': 'Tokyo', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 60}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 64}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 64}
# {'city': 'Nairobi', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 88}
# {'city': 'Pittsburgh', 'timestamp': '2026-01-27 19:07:30', 'temperature_f': 64}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 21
#      10 consumer = KafkaConsumer(
#      11     "lab02-jthuo",  # [TODO]: Use your topic variable here
#      12     bootstrap_servers=["localhost:9092"],  # [TODO]: Same bootstrap server as producer
#    (...)
#      17     auto_commit_interval_ms=1000
#      18 )
#      20 print('Reading Kafka Broker')
# ---> 21 for message in consumer:
#      22     # Producer serialized to JSON bytes, so we decode and parse
#      23     message_str = message.value.decode('utf-8')
#      24     message_dict = loads(message_str)
#
# File ~/cmu_workspace/spring2026/MLiP/lab2/.lab2/lib/python3.10/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/cmu_workspace/spring2026/MLiP/lab2/.lab2/lib/python3.10/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/cmu_workspace/spring2026/MLiP/lab2/.lab2/lib/python3.10/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/cmu_workspace/spring2026/MLiP/lab2/.lab2/lib/python3.10/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/cmu_workspace/spring2026/MLiP/lab2/.lab2/lib/python3.10/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/cmu_workspace/spring2026/MLiP/lab2/.lab2/lib/python3.10/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /usr/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
# [TODO]: Use kcat to consume the first 5 messages from your topic. Use the -f flag to include the offset in the output.
# Example command structure:
# kcat -b localhost:<local_port> -t <your_topic_name> -C -o earliest -c 5 -f "%o: %s\n"
# 
# Where:
# - -b: broker address (same port as your SSH tunnel)
# - -t: your topic name (e.g., "lab02-asmith")
# - -C: consumer mode
# - -o earliest: start from earliest offset
# - -c 5: consume 5 messages
# - -f "%o: %s\n": format to show offset and message
#
# Paste the output below and explain what the offset refers to.
# !kafkacat -b localhost:9092 -t lab02-jthuo -C -o earliest -c 5 -f "%o: %s\n"
# Out:
# 0: {"city": "Tokyo", "timestamp": "2026-01-27 18:52:31", "temperature_f": 60}
# 1: {"city": "Tokyo", "timestamp": "2026-01-27 18:52:31", "temperature_f": 60}
# 2: {"city": "Pittsburgh", "timestamp": "2026-01-27 18:52:31", "temperature_f": 64}
# 3: {"city": "Pittsburgh", "timestamp": "2026-01-27 18:52:31", "temperature_f": 64}
# 4: {"city": "Pittsburgh", "timestamp": "2026-01-27 18:52:31", "temperature_f": 64}
